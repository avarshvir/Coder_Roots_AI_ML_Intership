# %%
# data visualization 
# matplotlib
# seaborn
# plolty-express

# %%
# !pip install seaborn 
# !pip install matplotlib

# %%
import seaborn as sns

# %%
# https://github.com/mwaskom/seaborn-data

# %%
df= sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1= sns.load_dataset('tips')
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# countplot

# %%
df.loc[:,'pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.loc[:,'alive'].value_counts()
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
sns.countplot(df,x='pclass')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(df,x='pclass', hue='alive')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(df,x='pclass', hue='alive',order=[3,2,1], hue_order=['no','yes'])
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(df,x='pclass', hue='alive',order=[3,2,1], hue_order=['no','yes']).set_title('Pclass Count')
# Out:
# Text(0.5, 1.0, 'Pclass COunt')

# %%
a=sns.countplot(df,x='pclass', hue='alive',order=[1,2,3], hue_order=['no','yes'])
a.set_title('Pclass Count')
a.set_xlabel('PClass')
a.set_ylabel('Count of PClass')
a.set_xticklabels(['Pclass_1','Pclass_2','Pclass_3'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13732\3225293814.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   a.set_xticklabels(['Pclass_1','Pclass_2','Pclass_3'])
# [Text(0, 0, 'Pclass_1'), Text(1, 0, 'Pclass_2'), Text(2, 0, 'Pclass_3')]

# %%
# Bar chart 
# a=[i for i in range(0,35,2)]

# %%
sns.barplot(df,y='age', hue='sex')
# Out:
# <Axes: ylabel='age'>

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#scatter plot

# %%
sns.scatterplot(df1,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(df1,x='total_bill',y='tip', hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(df1,x='total_bill',y='tip', hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
sns.catplot(df,x='pclass',y='age')

# %%
sns.catplot(df,x='pclass',y='age', hue='sex')

# %%
sns.catplot(df,x='pclass',y='age', hue='alive')

# %%
df2=sns.load_dataset('flights')

# %%
df2.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(df2, x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(df2, x='year',y='passengers', hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(penguins, x="flipper_length_mm")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
penguins.loc[:,"flipper_length_mm"].value_counts()
# Out:
# flipper_length_mm
# 190.0    22
# 195.0    17
# 187.0    16
# 193.0    15
# 210.0    14
# 191.0    13
# 215.0    12
# 197.0    10
# 196.0    10
# 185.0     9
# 220.0     8
# 198.0     8
# 208.0     8
# 216.0     8
# 212.0     7
# 186.0     7
# 181.0     7
# 189.0     7
# 230.0     7
# 192.0     7
# 184.0     7
# 199.0     6
# 213.0     6
# 188.0     6
# 214.0     6
# 217.0     6
# 222.0     6
# 201.0     6
# 219.0     5
# 209.0     5
# 218.0     5
# 221.0     5
# 203.0     5
# 194.0     5
# 180.0     5
# 178.0     4
# 225.0     4
# 228.0     4
# 202.0     4
# 200.0     4
# 182.0     3
# 224.0     3
# 205.0     3
# 229.0     2
# 183.0     2
# 207.0     2
# 223.0     2
# 211.0     2
# 231.0     1
# 206.0     1
# 174.0     1
# 172.0     1
# 179.0     1
# 176.0     1
# 226.0     1
# Name: count, dtype: int64
