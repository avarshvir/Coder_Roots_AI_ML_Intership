# %%
import pandas as pd

# %%
df= pd.read_csv('income.csv')

# %%
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
df['Income($)'].min()
# Out:
# 45000

# %%
df['Income($)'].max()
# Out:
# 162000

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler= MinMaxScaler(feature_range=(0,100))

# %%
scaler.fit(df.loc[:,['Income($)']])
# Out:
# MinMaxScaler(feature_range=(0, 100))

# %%
a= scaler.transform(df.loc[:,['Income($)']])

# %%
a
# Out:
# array([[ 21.36752137],
#        [ 38.46153846],
#        [ 13.67521368],
#        [ 12.82051282],
#        [ 89.74358974],
#        [ 94.01709402],
#        [ 98.29059829],
#        [100.        ],
#        [ 94.87179487],
#        [ 72.64957265],
#        [ 78.63247863],
#        [  0.        ],
#        [  2.56410256],
#        [  5.12820513],
#        [  3.84615385],
#        [  6.83760684],
#        [ 17.09401709],
#        [ 15.38461538],
#        [ 16.23931624],
#        [ 29.91452991],
#        [ 31.62393162],
#        [ 11.11111111]])

# %%
df1= pd.read_csv('height-weight.csv')

# %%
df1.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale= StandardScaler()  #z = (x - u) / s  --- s is standard deviation, u is mean of the data, x is current value

# %%
scale.fit_transform(df1.loc[:,['Weight','Height']])
# Out:
# array([[-1.64913128, -2.01183323],
#        [-0.90540541, -1.22578288],
#        [-1.47750223, -1.85462316],
#        [-0.79098604, -0.7017493 ],
#        [-0.21888922,  0.08430105],
#        [ 0.23878824,  0.18910777],
#        [ 0.3532076 ,  0.24151112],
#        [ 0.92530443,  0.87035141],
#        [ 1.21135284,  1.23717491],
#        [ 0.23878824,  0.60833462],
#        [ 0.46762697,  0.92275477],
#        [ 1.21135284,  1.23717491],
#        [ 1.78344966,  0.87035141],
#        [ 1.49740125,  1.28957827],
#        [ 0.63925602,  0.60833462],
#        [ 0.23878824,  0.97515812],
#        [-1.36308287, -0.96376609],
#        [-0.50493763,  0.0318977 ],
#        [ 0.12436887, -0.43973252],
#        [ 0.75367538,  0.45112455],
#        [-1.64913128, -1.54020302],
#        [-1.01982477, -0.96376609],
#        [-0.10446985,  0.08430105]])

# %%
df1.loc[:,['new_weight','new_height']]=scale.fit_transform(df1.loc[:,['Weight','Height']])

# %%
df1
# Out:
#     Weight  Height  new_weight  new_height
# 0       45     120   -1.649131   -2.011833
# 1       58     135   -0.905405   -1.225783
# 2       48     123   -1.477502   -1.854623
# 3       60     145   -0.790986   -0.701749
# 4       70     160   -0.218889    0.084301
# 5       78     162    0.238788    0.189108
# 6       80     163    0.353208    0.241511
# 7       90     175    0.925304    0.870351
# 8       95     182    1.211353    1.237175
# 9       78     170    0.238788    0.608335
# 10      82     176    0.467627    0.922755
# 11      95     182    1.211353    1.237175
# 12     105     175    1.783450    0.870351
# 13     100     183    1.497401    1.289578
# 14      85     170    0.639256    0.608335
# 15      78     177    0.238788    0.975158
# 16      50     140   -1.363083   -0.963766
# 17      65     159   -0.504938    0.031898
# 18      76     150    0.124369   -0.439733
# 19      87     167    0.753675    0.451125
# 20      45     129   -1.649131   -1.540203
# ...

# %%
# Linear Regression -- for regression problems
# Logistic Regression -- for classification 
# Decision Tree -- for both
# Random Forest - for both
# KNN 
# SVM
#Unsupervised--  
# K-Means

# Deep learning -- 
# Neural Networks
# ANN
# CNN

# NLP-- Spacy, NLTK
# DL- RNN 
# OpenCV
# Reinforcement 


# Extras-- 
# Encoder, Decoders, transformers 

# GenAI
